# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.proxies import GenericProxyConfig

# %%
video_id = "aDG1T0kJnd4"

# %%
ytt_api = YouTubeTranscriptApi(
    # proxy_config=GenericProxyConfig(
    #     http_url="http://zyemvwms:qlzmv0bmdepa@23.95.150.145:6114/",
    #     https_url="http://zyemvwms:qlzmv0bmdepa@23.95.150.145:6114/",
    # )
)

# %%
l1 = ytt_api.list("NzZXz3fJf6o")

# %%
for transcript in l1:

    # the Transcript object provides metadata properties
    print(f"Video ID: {transcript.video_id}")
    print(f"Language: {transcript.language}")
    print(f"Language Code: {transcript.language_code}")
    print(f"Is Generated: {transcript.is_generated}")
    print(f"Is Translatable: {transcript.is_translatable}")
    print(f"Translation Languages: {transcript.translation_languages}")
    print("-" * 50)

    # fetch the actual transcript data
    transcript_data = transcript.fetch(preserve_formatting=True)
    
    # print the transcript data
    print(transcript_data)
# Out:
# Video ID: NzZXz3fJf6o
# Language: Bangla
# Language Code: bn
# Is Generated: False
# Is Translatable: True
# ...

# %%
have = l1.find_transcript(["en"])

# %%
have.fetch(preserve_formatting=True)
# Out:
# ---------------------------------------------------------------------------
# IpBlocked                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 have.fetch(preserve_formatting=True)
#
# File c:\Users\Shani\AppData\Local\Programs\Python\Python312\Lib\site-packages\youtube_transcript_api\_transcripts.py:139, in Transcript.fetch(self, preserve_formatting)
#     136     raise PoTokenRequired(self.video_id)
#     137 response = self._http_client.get(self._url)
#     138 snippets = _TranscriptParser(preserve_formatting=preserve_formatting).parse(
# --> 139     _raise_http_errors(response, self.video_id).text,
#     140 )
#     141 return FetchedTranscript(
#     142     snippets=snippets,
#     143     video_id=self.video_id,
#    (...)
#     146     is_generated=self.is_generated,
#     147 )
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 72
#      69 yt_transcriber = YouTubeTranscriber(video_id)
#      71 # 1. Get a list of available languages
# ---> 72 languages = yt_transcriber.get_available_languages()
#      73 if languages:
#      74     print("Available languages:", languages)
#
# Cell In[41], line 17, in YouTubeTranscriber.get_available_languages(self)
#      11 """
#      12 Lists all available language codes for the video's transcripts.
#      13 Returns:
#      14     A list of language codes (e.g., ['en', 'es', 'fr']), or None if no transcripts are found.
#      15 """
#      16 try:
# ---> 17     transcript_list = YouTubeTranscriptApi.list_transcripts(self.video_id)
#      18     return [t.language_code for t in transcript_list]
#      19 except (NoTranscriptFound, VideoUnavailable, TranscriptsDisabled) as e:
#
# ...

# %%
# Out:
# ...
# 🔍 YOUTUBE TRANSCRIPT API - IP STATUS CHECK
# ...
# 🧪 Testing IP status with a known video...
# ✅ IP appears to be working fine
#
# 📋 Example 1: Basic transcription
# 📺 Attempting to transcribe video: NzZXz3fJf6o
# Error fetching transcript: name 'TooManyRequests' is not defined
# ❌ All attempts failed
#
# 📋 Example 2: Using Webshare proxy
# # Uncomment and configure if you have Webshare credentials:
# # proxy_config = {
# #     'type': 'webshare',
# #     'username': 'your_username',
# #     'password': 'your_password',
# #     'locations': ['us', 'ca']  # Optional
# # }
# # result = safe_transcribe_video(video_url, use_proxy=True, proxy_config=proxy_config)
#
# 📋 Example 3: Using generic proxy
# # proxy_config = {
# #     'type': 'generic',
# #     'http_url': 'http://user:pass@proxy.com:8080',
# #     'https_url': 'https://user:pass@proxy.com:8080'
# # }
# # result = safe_transcribe_video(video_url, use_proxy=True, proxy_config=proxy_config)
#
# ...
